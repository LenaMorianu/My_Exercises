# %%
# !pip install nba_api

# %%
from nba_api.stats.static import teams

# %%
nba_teams = teams.get_teams()

# %%
nba_teams[:5]
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Atlanta',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966}]

# %%
# We can convert the dictionary to a table

def one_dict(list_dict):
    keys = list_dict[0].keys()
    out_dict = {key:[] for key in keys}
    for dict_ in list_dict:
        for key,value in dict_.items():
            out_dict[key].append(value)
    return out_dict

dict_nba_team = one_dict(nba_teams)

# %%
import pandas as pd

# %%
# Convert the dictionary to a DataFrame

df_teams = pd.DataFrame(dict_nba_team)
df_teams.head()
# Out:
#            id             full_name abbreviation   nickname         city  \
# 0  1610612737         Atlanta Hawks          ATL      Hawks      Atlanta
# 1  1610612738        Boston Celtics          BOS    Celtics       Boston
# 2  1610612739   Cleveland Cavaliers          CLE  Cavaliers    Cleveland
# 3  1610612740  New Orleans Pelicans          NOP   Pelicans  New Orleans
# 4  1610612741         Chicago Bulls          CHI      Bulls      Chicago
#
#            state  year_founded
# 0        Atlanta          1949
# 1  Massachusetts          1946
# 2           Ohio          1970
# 3      Louisiana          2002
# 4       Illinois          1966

# %%
df_warriors = df_teams[df_teams["nickname"]=="Warriors"]
df_warriors
# Out:
#            id              full_name abbreviation  nickname          city  \
# 7  1610612744  Golden State Warriors          GSW  Warriors  Golden State
#
#         state  year_founded
# 7  California          1946

# %%
id_warriors = df_warriors[["id"]].values[0][0]

# %%
id_warriors
# Out:
# 1610612744

# %%
# The function LeagueGameFinder will make an API call

from nba_api.stats.endpoints import leaguegamefinder

gamefinder = leaguegamefinder.LeagueGameFinder(team_id_nullable = id_warriors)

# %%
games = gamefinder.get_data_frames()[0]   # All the games the Warriors played

games.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     22019  1610612744               GSW  Golden State Warriors  0021900967
# 1     22019  1610612744               GSW  Golden State Warriors  0021900944
# 2     22019  1610612744               GSW  Golden State Warriors  0021900929
# 3     22019  1610612744               GSW  Golden State Warriors  0021900913
# 4     22019  1610612744               GSW  Golden State Warriors  0021900901
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  ...  FT_PCT  OREB  DREB   REB  AST  \
# 0  2020-03-10  GSW vs. LAC  L  239  107  ...   0.815   4.0  31.0  35.0   25
# 1  2020-03-07  GSW vs. PHI  W  240  118  ...   0.750   7.0  28.0  35.0   30
# 2  2020-03-05  GSW vs. TOR  L  240  113  ...   0.760  14.0  38.0  52.0   34
# 3  2020-03-03    GSW @ DEN  W  239  116  ...   0.636   5.0  30.0  35.0   31
# 4  2020-03-01  GSW vs. WAS  L  239  110  ...   0.708  18.0  34.0  52.0   25
#
#    STL  BLK  TOV  PF  PLUS_MINUS
# ...

# %%
# We can create 2 DataFrames: one with the games the Warriors faced the raptors at home, and a second for away games

games_home = games[games["MATCHUP"]=="GSW vs. TOR"]
games_away = games[games["MATCHUP"]=="GSW @ TOR"]
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME  \
# 2        22019  1610612744               GSW  Golden State Warriors
# 73       22019  1610612744               GSW  Golden State Warriors
# 78       42018  1610612744               GSW  Golden State Warriors
# 80       42018  1610612744               GSW  Golden State Warriors
# 81       42018  1610612744               GSW  Golden State Warriors
# 153      22018  1610612744               GSW  Golden State Warriors
# 293      22017  1610612744               GSW  Golden State Warriors
# 374      22016  1610612744               GSW  Golden State Warriors
# 514      22015  1610612744               GSW  Golden State Warriors
# 532      12015  1610612744               GSW  Golden State Warriors
# 611      22014  1610612744               GSW  Golden State Warriors
# 725      22013  1610612744               GSW  Golden State Warriors
# 791      22012  1610612744               GSW  Golden State Warriors
# ...

# %%
# We can plot out the Plus_Minus column for both DataFrame

import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
games_away.plot(x = "GAME_DATE",y="PLUS_MINUS",ax = ax)
games_home.plot(x = "GAME_DATE",y="PLUS_MINUS",ax = ax)

ax.legend(["away","home"])
plt.show()
